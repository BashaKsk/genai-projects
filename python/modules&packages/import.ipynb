# %%
import math
math.sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import sqrt, pi

print(sqrt(2))
pi
# Out:
# 1.4142135623730951
# 3.141592653589793

# %%
import numpy as np

np.array([1,2,34])
# Out:
# array([ 1,  2, 34])

# %%
from math import *


sqrt(12)
pi
# Out:
# 3.141592653589793

# %%
from package.maths import *

sub1(3,1)
addition(1,2)
# Out:
# 3
