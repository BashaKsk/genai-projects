# %%
import array
arr = array.array('i', [1,2,3,4])

arr
# Out:
# array('i', [1, 2, 3, 4])

# %%
import random

random.randint(1,2)




# for i in range(1,5):
#     print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
## File and directory Access

import os

print(os.getcwd())
# Out:
# /home/basha/Desktop/genai/python

# %%
os.mkdir('tes_dir')

# %%
## Hight level operation

import shutil


shutil.copyfile('source.txt', 'des.txt')
# Out:
# 'des.txt'

# %%
## Data Serialization
import json

data = {'name' : 'basha', 'age': 25 }

json_str = json.dumps(data)

print(type(json_str))
json_str
# Out:
# <class 'str'>
# '{"name": "basha", "age": 25}'

# %%
parsed_json = json.loads(json_str)


print(type(parsed_json))

parsed_json
# Out:
# <class 'dict'>
# {'name': 'basha', 'age': 25}

# %%
import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['basha', 24])

# %%
with open ('example.csv', mode='r') as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['basha', '24']

# %%
from datetime import datetime, timedelta

now=datetime.now()

print(now)

yesterday = now - timedelta(days=2)

print(yesterday)
# Out:
# 2026-05-22 16:33:57.820484
# 2026-05-20 16:33:57.820484

# %%
## time
import time

print(time.time())

time.sleep(2)

print(time.time())
# Out:
# 1779448417.927599
# 1779448419.9284763

# %%
## regulare expressions


import re

pattern = r'\d+'

text = 'There are 123 apples 456'

match = re.search(pattern, text)

print(match.group())
# Out:
# 123
